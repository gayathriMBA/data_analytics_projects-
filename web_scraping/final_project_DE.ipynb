# %%
import requests
import time
import pandas as pd
from parsel import Selector
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager

# Setup Selenium WebDriver
chrome_options = Options()
chrome_options.add_argument("--headless")  # Run in headless mode (no browser UI)
chrome_options.add_argument("--disable-gpu")
chrome_options.add_argument("--no-sandbox")
chrome_options.add_argument("--window-size=1920x1080")

service = Service(ChromeDriverManager().install())
driver = webdriver.Chrome(service=service, options=chrome_options)

# List of category URLs
living_room_urls = [
    "https://store.hermanmiller.com/living-room-furniture/constant/loung-chairs?lang=en_US",
    "https://store.hermanmiller.com/living-room-furniture/constant/accent-coffee-tables?lang=en_US",
    "https://store.hermanmiller.com/living-room-furniture/constant/chairs?lang=en_US",
    "https://store.hermanmiller.com/living-room-furniture/constant/sofas-sleepers?lang=en_US",
]

base_url = "https://store.hermanmiller.com"

full_links = []

# ✅ Step 1: Fetch product links from all categories (Requests + Parsel)
for url in living_room_urls:
    response = requests.get(url, headers={"User-Agent": "Mozilla/5.0"})
    
    if response.status_code == 200:
        sel = Selector(text=response.text)
        
        # ✅ Extract product links
        links = sel.css('div.pdp-link a::attr(href)').getall()
        full_links.extend([base_url + link if not link.startswith("http") else link for link in links])
    
    else:
        print(f"Failed to fetch {url}, Status Code: {response.status_code}")

def scrape_product_details(url):
    """Scrape product details from each product page using Selenium."""
    try:
        time.sleep(2)  # Prevent rate limiting
        driver.get(url)
        sel = Selector(text=driver.page_source)  # Convert Selenium page source to Parsel Selector

        # ✅ Extract product details
        name = sel.css('h1.product-name::text').get(default="No name").strip()
        discount = sel.css('span.pricing-sale-percent::text').get(default="No discount").strip()
        price = sel.css('#maincontent span.pricing-default.has-list-price > span >span::text').get(default="No price").strip()

        # ✅ Extract new fields
        material = sel.css('#pdpSummaryMaterials > div > ul > li:nth-child(1) > span::text').get(default="No material").strip()
        designer = sel.css('#pdpSummaryDesigners > div > div > div > div.pdp-summary-designers-bio > p.pdp-summary-designers-name.h7::text').get(default="No designer").strip()
        item_no = sel.css('div.product-peak-wrap span span::text').get(default="No Item No.").strip()
        warranty = sel.css('div#warranty-value-proposition p span::text').get(default="No warranty info").strip()

        return {
            "Name": name,
            "Discount": discount,
            "Price": price,
            "Item No.": item_no,
            "Material": material,
            "Designer": designer,
            "Warranty": warranty,
        }
    
    except Exception as e:
        print(f"Error scraping {url}: {e}")
        return None

# ✅ Step 2: Scrape product details from all extracted links (Selenium)
all_products = []
for link in full_links:
    product_details = scrape_product_details(link)
    if product_details:
        all_products.append(product_details)

# ✅ Step 3: Convert to DataFrame and save to CSV
living_room_df = pd.DataFrame(all_products)
living_room_df.to_csv("herman_miller_products_cleaned.csv", index=False)

# Close Selenium WebDriver
driver.quit()
living_room_df
# Out:
#                                                  Name Discount      Price  \
# 0                      Eames Lounge Chair and Ottoman  25% off  $5,921.25
# 1   Eames Molded Plywood Lounge Chair Wood Base (LCW)  25% off  $1,046.25
# 2                      Eames Lounge Chair and Ottoman  25% off  $6,746.25
# 3                                  Eames Lounge Chair  25% off  $4,046.25
# 4                                    Rohde Easy Chair  25% off  $4,196.25
# ..                                                ...      ...        ...
# 72                                  Luva Modular Sofa  25% off  $5,572.50
# 73                            Nelson Marshmallow Sofa  25% off  $4,496.25
# 74                                  Luva Modular Sofa  25% off  $7,923.75
# 75                                        Striad Sofa  25% off  $5,838.75
# 76                                        Striad Sofa  25% off  $5,066.25
#
#      Item No.                                           Material  \
# 0   100083357  Seven-ply walnut, santos palisander, white ash...
# 1      117630                      Molded five-ply seat and back
# 2   100559409  Seven-ply walnut, santos palisander, white ash...
# 3   100195712  Seven-ply walnut, santos palisander, white ash...
# 4   100553310                           Solid oak or walnut legs
# ..        ...                                                ...
# 72  100646888                                        Steel frame
# 73  100590820                        Brushed tubular steel frame
# 74  100647132                                        Steel frame
# 75  100645518  Polyester-based molded shell; molded natural f...
# 76  100645443  Polyester-based molded shell; molded natural f...
#
#                        Designer         Warranty
# 0         Charles and Ray Eames  5-year warranty
# 1         Charles and Ray Eames  5-year warranty
# 2         Charles and Ray Eames  5-year warranty
# 3         Charles and Ray Eames  5-year warranty
# 4                 Gilbert Rohde  5-year warranty
# ..                          ...              ...
# 72                  Gabriel Tan  5-year warranty
# 73                George Nelson  5-year warranty
# 74                  Gabriel Tan  5-year warranty
# 75  Markus Jehs and Jürgen Laub  5-year warranty
# 76  Markus Jehs and Jürgen Laub  5-year warranty
#
# [77 rows x 7 columns]

# %%
import requests
import time
import pandas as pd
from parsel import Selector
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager

# Setup Selenium WebDriver
chrome_options = Options()
chrome_options.add_argument("--headless")  # Run in headless mode (no browser UI)
chrome_options.add_argument("--disable-gpu")
chrome_options.add_argument("--no-sandbox")
chrome_options.add_argument("--window-size=1920x1080")

service = Service(ChromeDriverManager().install())
driver = webdriver.Chrome(service=service, options=chrome_options)

# List of category URLs
storage_urls = [
    "https://store.hermanmiller.com/shelving-storage/constant/home-office-storage-hm?lang=en_US",
    "https://store.hermanmiller.com/shelving-storage/constant/bookcases-shelves?lang=en_US",
    "https://store.hermanmiller.com/shelving-storage/constant/dressers-hm?lang=en_US",
]

base_url = "https://store.hermanmiller.com"

full_links = []

# ✅ Step 1: Fetch product links from all categories (Requests + Parsel)
for url in storage_urls:
    response = requests.get(url, headers={"User-Agent": "Mozilla/5.0"})
    
    if response.status_code == 200:
        sel = Selector(text=response.text)
        
        # ✅ Extract product links
        links = sel.css('div.pdp-link a::attr(href)').getall()
        full_links.extend([base_url + link if not link.startswith("http") else link for link in links])
    
    else:
        print(f"Failed to fetch {url}, Status Code: {response.status_code}")

def scrape_product_details(url):
    """Scrape product details from each product page using Selenium."""
    try:
        time.sleep(2)  # Prevent rate limiting
        driver.get(url)
        sel = Selector(text=driver.page_source)  # Convert Selenium page source to Parsel Selector

        # ✅ Extract product details
        name = sel.css('h1.product-name::text').get(default="No name").strip()
        discount = sel.css('span.pricing-sale-percent::text').get(default="No discount").strip()
        price = sel.css('#maincontent span.pricing-default.has-list-price > span >span::text').get(default="No price").strip()

        # ✅ Extract new fields
        material = sel.css('#pdpSummaryMaterials > div > ul > li:nth-child(1) > span::text').get(default="No material").strip()
        designer = sel.css('#pdpSummaryDesigners > div > div > div > div.pdp-summary-designers-bio > p.pdp-summary-designers-name.h7::text').get(default="No designer").strip()
        item_no = sel.css('div.product-peak-wrap span span::text').get(default="No Item No.").strip()
        warranty = sel.css('div#warranty-value-proposition p span::text').get(default="No warranty info").strip()

        return {
            "Name": name,
            "Discount": discount,
            "Price": price,
            "Item No.": item_no,
            "Material": material,
            "Designer": designer,
            "Warranty": warranty,
        }
    
    except Exception as e:
        print(f"Error scraping {url}: {e}")
        return None

# ✅ Step 2: Scrape product details from all extracted links (Selenium)
all_products = []
for link in full_links:
    product_details = scrape_product_details(link)
    if product_details:
        all_products.append(product_details)

# ✅ Step 3: Convert to DataFrame and save to CSV
storage_df = pd.DataFrame(all_products)
storage_df.to_csv("herman_miller_storage_products.csv", index=False)

# Close Selenium WebDriver
driver.quit()
storage_df
# Out:
#                                    Name Discount      Price   Item No.  \
# 0             Tu W-Pull Mobile Pedestal  25% off    $281.25  100060241
# 1                           OE1 Trolley  25% off    $371.25  100202810
# 2   Tu W-Pull Freestanding Lateral File  25% off    $521.25    9176689
# 3                           OE1 Trolley  25% off    $461.25  100202816
# 4                    Line File Pedestal  25% off    $971.25     727679
# 5                Tu W-Pull Storage Case  25% off    $521.25  100080514
# 6                       OE1 Shelf Liner  25% off     $37.50  100202842
# 7                           OE1 Trolley  25% off    $296.25  100202802
# 8       Tu W-Pull Freestanding Pedestal  25% off    $281.25  100080536
# 9                          Line Console  25% off  $2,696.25  100143633
# 10                            Uten Silo  15% off    $522.75     611367
# 11                  OE1 Trolley Cushion  25% off     $93.75  100202852
# 12                            Uten Silo  15% off    $412.25     611442
# 13                   Eames Storage Unit  25% off  $1,646.25     194891
# 14                   Eames Storage Unit  25% off  $2,996.25     194884
# 15                       Story Bookcase  25% off    $296.25  100562020
# 16                       Story Bookcase  25% off    $296.25  100562024
# 17                          Tu Bookcase  25% off    $521.25  100071322
# 18                   Eames Storage Unit  25% off    $971.25  100074720
# 19                   Eames Storage Unit  25% off    $596.25  100074719
# 20      Nelson Thin Edge 3-Drawer Chest  25% off  $3,746.25  100145137
# 21      Nelson Thin Edge Double Dresser  25% off  $5,621.25   10002007
# 22      Nelson Thin Edge 4-Drawer Chest  25% off  $3,896.25   10001994
#
#                                              Material  \
# 0                                 Powder-coated steel
# 1                Tubular steel and formed sheet metal
# 2                                 Powder-coated steel
# 3                Tubular steel and formed sheet metal
# 4   Solid American walnut, white oak, or painted a...
# 5                                 Powder-coated steel
# 6             Hush fabric, 80% polyester, 20% viscose
# 7                Tubular steel and formed sheet metal
# 8                                 Powder-coated steel
# 9   Solid American walnut, white oak, or painted a...
# 10                                   ABS plastic body
# 11  Maharam Mode fabric, 80% post-consumer recycle...
# 12                                   ABS plastic body
# 13                             Molded plywood shelves
# 14                             Molded plywood shelves
# 15  Galvanized steel column with powder-coated alu...
# 16  Galvanized steel column with powder-coated alu...
# 17                                Powder-coated steel
# 18                             Molded plywood shelves
# 19                             Molded plywood shelves
# 20  Walnut, white ash, or santos palisander veneer...
# 21  Walnut, white ash or santos palisander veneer ...
# 22  Walnut, white ash or santos palisander veneer ...
#
#                    Designer          Warranty
# 0               No designer  12-year warranty
# 1   Sam Hecht and Kim Colin  12-year warranty
# 2               No designer  12-year warranty
# 3   Sam Hecht and Kim Colin  12-year warranty
# 4               Nathan Yong   1-year warranty
# 5               No designer  12-year warranty
# 6   Sam Hecht and Kim Colin   5-year warranty
# 7   Sam Hecht and Kim Colin  12-year warranty
# 8               No designer  12-year warranty
# 9               Nathan Yong   1-year warranty
# 10          Dorothee Becker   5-year warranty
# 11  Sam Hecht and Kim Colin   5-year warranty
# 12          Dorothee Becker   5-year warranty
# 13    Charles and Ray Eames   5-year warranty
# 14    Charles and Ray Eames   5-year warranty
# 15                 Afteroom   2-year warranty
# 16                 Afteroom   2-year warranty
# 17              No designer  12-year warranty
# 18    Charles and Ray Eames   5-year warranty
# 19    Charles and Ray Eames   5-year warranty
# 20            George Nelson   5-year warranty
# 21            George Nelson   5-year warranty
# 22            George Nelson   5-year warranty

# %%
import requests
import time
import pandas as pd
from parsel import Selector
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager

# Setup Selenium WebDriver
chrome_options = Options()
chrome_options.add_argument("--headless")  # Run in headless mode (no browser UI)
chrome_options.add_argument("--disable-gpu")
chrome_options.add_argument("--no-sandbox")
chrome_options.add_argument("--window-size=1920x1080")

service = Service(ChromeDriverManager().install())
driver = webdriver.Chrome(service=service, options=chrome_options)

# List of category URLs (Decor products)
decor_urls = [
    "https://store.hermanmiller.com/decor/constant/art?lang=en_US",
    "https://store.hermanmiller.com/decor/constant/pillows-hm?lang=en_US",
    "https://store.hermanmiller.com/decor/constant/rugs?lang=en_US",
]

base_url = "https://store.hermanmiller.com"

full_links = []

# ✅ Step 1: Fetch product links from all categories (Requests + Parsel)
for url in decor_urls:
    response = requests.get(url, headers={"User-Agent": "Mozilla/5.0"})
    
    if response.status_code == 200:
        sel = Selector(text=response.text)
        
        # ✅ Extract product links
        links = sel.css('div.pdp-link a::attr(href)').getall()
        full_links.extend([base_url + link if not link.startswith("http") else link for link in links])
    
    else:
        print(f"Failed to fetch {url}, Status Code: {response.status_code}")

def scrape_product_details(url):
    """Scrape product details from each product page using Selenium."""
    try:
        time.sleep(2)  # Prevent rate limiting
        driver.get(url)
        sel = Selector(text=driver.page_source)  # Convert Selenium page source to Parsel Selector

        # ✅ Extract product details
        name = sel.css('h1.product-name::text').get(default="No name").strip()
        discount = sel.css('span.pricing-sale-percent::text').get(default="No discount").strip()
        price = sel.css('#maincontent span.pricing-default.has-list-price > span >span::text').get(default="No price").strip()

        # ✅ Extract new fields
        material = sel.css('#pdpSummaryMaterials > div > ul > li:nth-child(1) > span::text').get(default="No material").strip()
        designer = sel.css('#pdpSummaryDesigners > div > div > div > div.pdp-summary-designers-bio > p.pdp-summary-designers-name.h7::text').get(default="No designer").strip()
        item_no = sel.css('div.product-peak-wrap span span::text').get(default="No Item No.").strip()
        warranty = sel.css('div#warranty-value-proposition p span::text').get(default="No warranty info").strip()

        return {
            "Name": name,
            "Discount": discount,
            "Price": price,
            "Item No.": item_no,
            "Material": material,
            "Designer": designer,
            "Warranty": warranty,
        }
    
    except Exception as e:
        print(f"Error scraping {url}: {e}")
        return None

# ✅ Step 2: Scrape product details from all extracted links (Selenium)
all_products = []
for link in full_links:
    product_details = scrape_product_details(link)
    if product_details:
        all_products.append(product_details)

# ✅ Step 3: Convert to DataFrame and save to CSV
decor_df = pd.DataFrame(all_products)
decor_df.to_csv("herman_miller_decor_products.csv", index=False)

# Close Selenium WebDriver
driver.quit()
decor_df
# Out:
#                                      Name Discount       Price   Item No.  \
# 0                   Hot Dog Picnic Poster  25% off     $671.25  100487604
# 1                      Girard Geometric E  25% off     $146.25  100400155
# 2                    Deluxx Visions Print  20% off     $200.00  100606845
# 3    Nelson Pop Art Blue and Black Poster  25% off     $408.75  100291491
# 4                  Come Fly With Me Print  20% off     $200.00  100606844
# ..                                    ...      ...         ...        ...
# 96          Merger Rug by Hella Jongerius  30% off   $4,665.50  100085192
# 97                     Maharam Margin Rug  25% off   $2,283.75  100193102
# 98                      Maharam Swell Rug  25% off   $2,471.25  100193153
# 99       Multitone Rug by Hella Jongerius  25% off   $4,368.75   10004799
# 100         Argali Rug by Hella Jongerius  25% off  $10,001.25  100085979
#
#                                               Material  \
# 0                                 American maple frame
# 1                                    100% cotton paper
# 2                                 Archival pigment ink
# 3    American maple frame with natural, white, or b...
# 4                                 Archival pigment ink
# ..                                                 ...
# 96                                80% wool, 20% cotton
# 97                                          100% Wool.
# 98                                          100% Wool.
# 99                                           100% wool
# 100                           98% argali wool, 2% silk
#
#                    Designer         Warranty
# 0            Steve Frykholm  1-year warranty
# 1          Alexander Girard  1-year warranty
# 2    FAILE and Deluxx Fluxx  1-year warranty
# 3             George Nelson  1-year warranty
# 4    FAILE and Deluxx Fluxx  1-year warranty
# ..                      ...              ...
# 96          Hella Jongerius  2-year warranty
# 97    Maharam Design Studio  2-year warranty
# 98    Maharam Design Studio  2-year warranty
# 99          Hella Jongerius  2-year warranty
# 100         Hella Jongerius  2-year warranty
#
# [101 rows x 7 columns]
